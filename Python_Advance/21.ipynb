# %% [markdown]
# # Q1. What is a probability distribution, exactly? If the values are meant to be random, how can you predict them at all?

# %% [markdown]
# <li>Probability distribution gives the possibility of each outcome of a random experiment or event.</li>
# <li>We can predicting directly like this number will occur we predicting the possibility of occurence</li>

# %% [markdown]
# # Q2. Is there a distinction between true random numbers and pseudo-random numbers, if there is one? Why are the latter considered “good enough”?

# %% [markdown]
# <li>Both these categories of random numbers are produced with the help of generators</li>
# <li>random number generators use an unpredictable physical means to generate numbers (like voltage fluctuation)</li>
# <li>pseudo-random number generators use mathematical algorithms (completely computer-generated)</li>
# <li>pseudo-random numbers  are considered good enough because in most of the circumstances we dont require such level of unpredictability as shown by voltage fluctuaton, the artificial unpredictability generated by mathematical algos is good enough to create the random required for the event</li>

# %% [markdown]
# # Q3. What are the two main factors that influence the behaviour of a "normal" probability distribution?

# %% [markdown]
# <li>Mean and standard deviation</li>

# %% [markdown]
# # Q4. Provide a real-life example of a normal distribution.

# %% [markdown]
# <li>Attentive of a student while trying to study</li>

# %% [markdown]
# # Q5. In the short term, how can you expect a probability distribution to behave? What do you think will happen as the number of trials grows?

# %% [markdown]
# <li>The chance of getting succes increases as the increase the number of trials.Infact I think that the quote  "Practice makes a man Perfect" may have been derived from probaility theory only</li>

# %% [markdown]
# # Q6. What kind of object can be shuffled by using random.shuffle?

# %% [markdown]
# <li>Used to shuffle the original ordering of a list</li>

# %% [markdown]
# # Q7. Describe the math package's general categories of functions.

# %% [markdown]
# <ul>Quoting from the python documentation
# <li>Number-theoretic and representation functions
# <li>Power and logarithmic functions
# <li>Trigonometric functions
# <li>Angular conversion
# <li>Hyperbolic functions
# <li>Special functions
#
# </ul>

# %% [markdown]
# # Q8. What is the relationship between exponentiation and logarithms?

# %% [markdown]
# <li>log 2 base 4 = 2^what = 4</li>

# %% [markdown]
# # Q9. What are the three logarithmic functions that Python supports?

# %% [markdown]
# <ul>math.log(x[, base])
# <li>With one argument, return the natural logarithm of x (to base e)
# </ul>
# <ul>math.log2(x)
# <li>Return the base-2 logarithm of x.
# </ul>
# <ul>math.log10(x)
# <li>Return the base-10 logarithm of x. This is usually more accurate than log(x, 10)
# </ul>
