# %% [markdown]
# # 1. What does RGBA stand for?

# %% [markdown]
# <li>It stands for red,green,blue,alpha</li>
# <li>Thus its basically used to express a color in terms of these values</li>

# %% [markdown]
# # 2. From the Pillow module, how do you get the RGBA value of any images?

# %%
from PIL import Image
imgobj = Image.open('sample.jpg')
img_c = imgobj.convert('RGBA')
data = img_c.getdata()

# %%
list(data)
# Out:
# [(202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
#  (202, 229, 255, 255),
# ...

# %% [markdown]
# # 3. What is a box tuple, and how does it work?

# %% [markdown]
# <li>Quite a few Pillow functions take a box tuple as argument</li>
# <li>This indicates that the respective function is expecting 4 integer coordinates that describe a rectangle</li>
# <ul>The order of argumemts is as follows
#     <li>Left The x-coordinate of the leftmost edge of the box.</li>
#     <li>Top The y-coordinate of the top edge of the box.</li>
#     <li>Right The x-coordinate of one pixel to the right of the rightmost edge of the box. This integer must be greater than the left integer.</li>
#     <li>Bottom The y-coordinate of one pixel lower than the bottom edge of the box. This integer must be greater than the top integer.</li>
# </ul>
# <li>box includes the left and top coordinates and goes up to but does not include the right and bottom coordinates.</li>
# <li>For example, the box tuple (3, 1, 9, 6) represents all the pixels in the black box</li>

# %% [markdown]
# <img src='img.jpg'>

# %% [markdown]
# # 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?

# %%
from PIL import Image
img = Image.open('sample.jpg')
print(f"Width is {img.width}")
print(f"Height is {img.height}")
# Out:
# Width is 720
# Height is 893

# %% [markdown]
# # 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

# %%
from PIL import Image
import numpy as np

#Convert our image to RGBA
img = Image.open(r'sample.jpg').convert('RGBA')

#Get the imagee data in pur array
array = np.array(img)

#Excluding the lower left quarter by marking the pixels present over there as black
array[446: 893, 0 : 360] = (0, 0, 0,0) 

img = Image.fromarray(array)

img.show()

#saving the new image
img1 = img.save('img_1.jpg')

# %% [markdown]
# # 6. After making changes to an Image object, how could you save it as an image file?

# %% [markdown]
# <li>using img.save() as shown in last line of above code</li>

# %% [markdown]
# # 7. What module contains Pillow’s shape-drawing code?

# %% [markdown]
# <li>PIL.ImageDraw</li>

# %% [markdown]
# # 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?

# %%
import math 
from PIL import Image, ImageDraw 
  
#Giving dimensions of rectangle
width,height = 200,200
shape = [(100,100),(width - 20, height - 20)]

  
# creating new Image object of the given dimensions 
img = Image.new("RGBA", (width, height)) 
  
# Drawing the rectangle
img1 = ImageDraw.Draw(img)   
img1.rectangle(shape,outline ="red") 
img.show()

# %% [markdown]
# <li>PIL.ImageDraw object hace Draw()</li>
# <li>And this is how we get PIL.ImageDraw objects</li>
