# %% [markdown]
# # Challenge 1 Questions from 5 March Class

# %% [markdown]
#  <li>1 . Find out how many male and female passenger was onboarded .
# <li>2. how many survived we have .
# <li>3. how many casuality we have
# <li>4 . what is name of a person who is the eldest one .
# <li>5 . how many passenger do we have in first , second and third class
# <li>6. how many person we have whose name starts with "s"
# <li>7. try to create a new column which is a summation  of "SibSp" and "parch"
# <li>8 . how many person do we have below age of 25 .
# <li>9 . how many person died whose age was less then 40
# <li>10 . from a  cabin column seperate text and numeric value .

# %% [markdown]
# # Solutions

# %%
import pandas as pd

# %%
df =  pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %% [markdown]
# # 1

# %%
#method 1
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
#method 2
len(df[df['Sex']=='male'])
# Out:
# 577

# %%
#method 3
#method 1 internally method 3 ho rha hai
df.groupby("Sex")['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %% [markdown]
# # 2

# %%
#method 1
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
#method 2
len(df[df['Survived']==1])
# Out:
# 342

# %% [markdown]
# # 3

# %%
len(df[df['Survived']==0])
# Out:
# 549

# %% [markdown]
# # 4

# %%
df[df['Age'] == df["Age"].max()]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %% [markdown]
# # 5

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
#method 2
df.groupby('Pclass')['Pclass'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %% [markdown]
# # 6

# %%
len(df[df["Name"].str.startswith("S")]['Name'])
# Out:
# 86

# %% [markdown]
# # 7

# %%
df['New'] = df['SibSp'] + df['Parch']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 8

# %%
len(df[df['Age'] < 25])
# Out:
# 278

# %% [markdown]
# # 9

# %%
len(df[(df['Survived'] == 0) & (df['Age'])])
# Out:
# 424

# %% [markdown]
# # 10

# %%
import re

replace = re.compile("([a-zA-Z]+)")
df['string_cabin_list'] = df['Cabin'].str.extract(replace)
df['num_cabin_list'] = df['Cabin'].str.replace(replace,"")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New string_cabin_list  \
# 0      0         A/5 21171   7.2500   NaN        S    1               NaN
# 1      0          PC 17599  71.2833   C85        C    1                 C
# 2      0  STON/O2. 3101282   7.9250   NaN        S    0               NaN
# ...

# %% [markdown]
# # Challenge 2 Questions from 5 March class

# %%
df = pd.read_csv(r".\bank\bank.csv",sep=";")
df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# # dataset link - https://archive.ics.uci.edu/ml/datasets/Bank+Marketing
#
# <li>1 . how many campaign available in this dataset .
# <li>2 . how many users do we have with housing and personal loan .
# <li>3. how many person do we have whose age is 60+ .
# <li>4 . in which month we have trageted most of the customer .
# <li>5 . which mode of call is giving you more result
# <li>6 . how many enterpeures do we have in this list
# <li>7 . how many customers do we have with negative balance
# <li>8. prepare a group of data based on education level .

# %% [markdown]
# # 1

# %%
len(set(df['campaign']))
# Out:
# 32

# %%
#Method 2
len(df['campaign'].unique())
# Out:
# 32

# %% [markdown]
# # 2

# %%
len(df[(df['housing']=='yes') & (df['loan']=='yes')])
# Out:
# 406

# %% [markdown]
# # 3

# %%
len(df[df['age']>60])
# Out:
# 127

# %% [markdown]
# # 4

# %%
df['month'].value_counts().index[0]
# Out:
# 'may'

# %%
#or
df.groupby('month').count().sort_values(by='age',ascending = False).index[0]
# Out:
# 'may'

# %% [markdown]
# # 5

# %%
df['contact'].value_counts()
# Out:
# cellular     2896
# unknown      1324
# telephone     301
# Name: contact, dtype: int64

# %%
df_groupby = df.groupby(['contact','y']).count()
df_groupby
# Out:
#                 age   job  marital  education  default  balance  housing  \
# contact   y
# cellular  no   2480  2480     2480       2480     2480     2480     2480
#           yes   416   416      416        416      416      416      416
# telephone no    257   257      257        257      257      257      257
#           yes    44    44       44         44       44       44       44
# unknown   no   1263  1263     1263       1263     1263     1263     1263
#           yes    61    61       61         61       61       61       61
#
#                loan   day  month  duration  campaign  pdays  previous  \
# contact   y
# cellular  no   2480  2480   2480      2480      2480   2480      2480
#           yes   416   416    416       416       416    416       416
# telephone no    257   257    257       257       257    257       257
#           yes    44    44     44        44        44     44        44
# unknown   no   1263  1263   1263      1263      1263   1263      1263
# ...

# %%
df_groupby.loc['cellular'].loc['yes'][0]
#or
df_groupby.loc['cellular','yes'][0]
# Out:
# 416

# %%
df_groupby.loc['telephone'].loc['yes'][0]
#or
df_groupby.loc['telephone','yes'][0]
# Out:
# 44

# %%
df_groupby.loc['unknown'].loc['yes'][0]
#or
df_groupby.loc['unknown','yes'][0]
# Out:
# 61

# %%
max(df_groupby.loc['unknown','yes'][0],df_groupby.loc['telephone','yes'][0],df_groupby.loc['cellular','yes'][0])
# Out:
# 416

# %% [markdown]
# # 6

# %%
len(df[df['job']=='entrepreneur'])
# Out:
# 168

# %% [markdown]
# # 7

# %%
len(df[df['balance'] < 0])
# Out:
# 366

# %% [markdown]
# # 8

# %%
df.groupby('education').count()
# Out:
#             age   job  marital  default  balance  housing  loan  contact  \
# education
# primary     678   678      678      678      678      678   678      678
# secondary  2306  2306     2306     2306     2306     2306  2306     2306
# tertiary   1350  1350     1350     1350     1350     1350  1350     1350
# unknown     187   187      187      187      187      187   187      187
#
#             day  month  duration  campaign  pdays  previous  poutcome     y
# education
# primary     678    678       678       678    678       678       678   678
# secondary  2306   2306      2306      2306   2306      2306      2306  2306
# tertiary   1350   1350      1350      1350   1350      1350      1350  1350
# unknown     187    187       187       187    187       187       187   187

# %%
ls = []
for i in df['education'].unique():
    ls.append(df[df['education']==i])

# %%
ls[0]
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
ls[1]
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
ls[2]
# Out:
#       age            job   marital education default  balance housing loan  \
# 2      35     management    single  tertiary      no     1350     yes   no
# 3      30     management   married  tertiary      no     1476     yes  yes
# 5      35     management    single  tertiary      no      747      no   no
# 6      36  self-employed   married  tertiary      no      307     yes   no
# 8      41   entrepreneur   married  tertiary      no      221     yes   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4501   34     management   married  tertiary      no      297     yes   no
# 4506   42     unemployed  divorced  tertiary      no     -166      no   no
# 4509   51     technician   married  tertiary      no     2506      no   no
# 4517   57  self-employed   married  tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur    single  tertiary      no     1136     yes  yes
#
# ...

# %%
ls[3]
# Out:
#       age          job   marital education default  balance housing loan  \
# 20     38   management  divorced   unknown      no        0     yes   no
# 27     67      retired   married   unknown      no      696      no   no
# 49     61       admin.   married   unknown      no     4629     yes   no
# 132    43  blue-collar   married   unknown     yes     -715     yes   no
# 133    48       admin.   married   unknown      no        0     yes   no
# ...   ...          ...       ...       ...     ...      ...     ...  ...
# 4337   73      retired   married   unknown      no      519      no   no
# 4342   50  blue-collar   married   unknown      no     2284     yes   no
# 4428   48  blue-collar   married   unknown      no      439     yes   no
# 4471   59   management   married   unknown      no     3534      no   no
# 4508   42       admin.   married   unknown      no      642     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...
